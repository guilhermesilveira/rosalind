# %% [markdown]
# Exercício em http://rosalind.info/problems/revc/
#
# Resolvido por Guilherme Silveira
#
# Aprendendo biologia com a Vanessa Leiko Cardoso

# %%
dna_sequence = "..."

complement_for = {
    "A" : "T",
    "C" : "G",
    "G" : "C",
    "T" : "A"
}

complement = ""
for base in dna_sequence:
  complement += complement_for[base]
complement[::-1]
# Out:
# '...'

# %%
complement = ""
result = [complement_for[base] for base in dna_sequence][::-1]
"".join(result)
# Out:
# '...'

# %%
def complementor(x):
  return complement_for[x]

result = list(map(complementor, dna_sequence))
result.reverse()
"".join(result)
# Out:
# '...'
